# %% [markdown]
# # **MRI Musculoskeltal Parameter Reference Values:**
#
# This document reflects to some extent the geometric, contrast and NSA values on predominantly 1.5 Tesla Philips scanners $(\small 30 \text{ mT/m}; 150 \text{ sl rate})$. The values change as changes are introduce to improve the ratio of signal-resolution to scanning time, and in this regard, it is a continued work in progress.

# %% [markdown]
# # **KNEE**
#
# ||Unif|FoV|Acq VS|Rec VS|Slice|Gap|FOD|SENSE|Acq|K-sp|TR|TE|FA|TSE|ES|WFS|NSA|FS pulse
# |-||||||||||||||||||-
# |`Coronal T1 TSE`|CLEAR|150|0.55 - 0.6 $\times$ 0.65|0.3 - 0.35 |3|Default|RL|1.2|Cartesian|Asym|1800-3000|18|90|$\leq$6|6|0.8|2|NA
# |`Sagittal PD`|
